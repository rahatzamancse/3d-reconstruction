# %%
import neptune.new as neptune
from utils import *
import numpy as np

import seaborn as sns


import ipywidgets as ipw
from ipywidgets.embed import embed_minimal_html

from matplotlib import pyplot as plt

import plotly.express as px
from plotly.subplots import make_subplots
import pandas as pd
from tqdm import tqdm

# %matplotlib inline

def figures_to_html(figs, filename="dashboard.html"):
    dashboard = open(filename, 'w')
    dashboard.write("<html><head></head><body>" + "\n")
    for fig in figs:
        inner_html = fig.to_html().split('<body>')[1].split('</body>')[0]
        dashboard.write(inner_html)
    dashboard.write("</body></html>" + "\n")
    
sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'axes.grid' : False})

# %% [markdown]
# # First runs

# %%
with neptune.get_project(
    name='rahatzamancse/MPSE-on-LMNET-dataset', 
    api_token='eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3NDk5MWVkNS0wMDg4LTRmNTktYWQyZC0zNzUyNTg0MTY1MGYifQ=='
) as project:

    # Get dashboard with runs contributed by 'sophia' tagged 'cycleLR'
    run_table_df = project.fetch_runs_table(
        owner='rahatzamancse',
        tag='variation-VARIABLE_PROJECTION_NPOINTS'
    ).to_pandas()

    run_table_df.columns
# Out:
# https://app.neptune.ai/rahatzamancse/MPSE-on-LMNET-dataset/
# Remember to stop your project once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/project#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/rahatzamancse/MPSE-on-LMNET-dataset/metadata

# %%
cols = [
    'Results/Baseline/4point_ICP_EMD',
    'Results/Alignment/ICP/EMDx100',
    'Results/Baseline/4point_ICP_Chamfer',
    'Results/Alignment/ICP/chamfer_distancex100',
    'Results/Final Cost',

    'parameters/DATASET',
    
    'parameters/N_PERSPECTIVE',
    'parameters/PROJECTION/POINT_IN_ATLEAST',
    'parameters/N_POINTS',
    
    'parameters/MPSE/SMART_INITIALIZATION',
    'parameters/MPSE/VARIABLE_PROJECTION',
    'parameters/PROJECTION/PROJ_TYPE',
    
    'sys/id',
    'runtime',
    'sys/tags'
]
colnames = [
    'Baseline EMD',
    'EMD',
    'Baseline Chamfer',
    'CD',
    'ROA',
    
    'Dataset',
    
    '# perspectives',
    'Points in exactly # perspectives',
    '# of Points',
    
    'Smart Initialization',
    'Variable Projection',
    'Projection Type',
    
    'exp_id',
    'Run Time (seconds)',
    'tags'
]

plot_df = run_table_df[
    run_table_df['parameters/PROJECTION/PROJ_TYPE'] == 'atleast_in_n_persp'
][cols]

plot_df.columns = colnames

nulcols = colnames.copy()
nulcols.remove('Run Time (seconds)')

plot_df = plot_df.dropna(axis=0, subset=nulcols)
plot_df['Perspective Percentage'] = plot_df['Points in exactly # perspectives'] / plot_df['# perspectives']

plot_df['dataset_types'] = plot_df.Dataset.apply(lambda v: v.split(':')[1])

plot_df
# Out:
#       Baseline EMD       EMD  Baseline Chamfer        CD       ROA  \
# 0         5.061609  0.003746          4.833760  0.007492  0.002745
# 1         4.419010  0.077554          4.258464  0.154633  0.003015
# 2         4.840735  0.121790          4.808146  0.074281  0.009537
# 3         4.736901  0.003005          5.222466  0.006010  0.002882
# 4         5.819034  0.005294          6.077609  0.010589  0.002775
# ...            ...       ...               ...       ...       ...
# 2083      3.683762  0.256801          4.061566  0.234192  0.004293
# 2084      3.906527  2.184549          4.921673  2.266408  0.081946
# 2085      4.702619  5.097611          5.749883  5.884808  0.040647
# 2086      4.340096  0.005411          5.535902  0.010821  0.001729
# 2087      4.113156  3.697090          5.280951  4.691984  0.039968
#
#                                                 Dataset  # perspectives  \
# 0        ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2               4
# 1        ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2               4
# 2        ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2               4
# 3        ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2               4
# 4        ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2               4
# ...                                                 ...             ...
# 2083  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965               4
# 2084  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965               4
# 2085  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965               4
# 2086  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965               4
# 2087  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965               4
#
#       Points in exactly # perspectives  # of Points  Smart Initialization  \
# 0                                    3         2048                  True
# 1                                    3         2048                  True
# 2                                    3         1024                  True
# 3                                    3         1024                  True
# 4                                    3          512                  True
# ...                                ...          ...                   ...
# 2083                                 3          512                  True
# 2084                                 3          256                  True
# 2085                                 3          256                  True
# 2086                                 3          128                  True
# 2087                                 3          128                  True
#
#       Variable Projection     Projection Type          exp_id  \
# 0                   False  atleast_in_n_persp  MPSELMNET-2279
# 1                    True  atleast_in_n_persp  MPSELMNET-2278
# 2                   False  atleast_in_n_persp  MPSELMNET-2277
# 3                    True  atleast_in_n_persp  MPSELMNET-2276
# 4                   False  atleast_in_n_persp  MPSELMNET-2275
# ...                   ...                 ...             ...
# 2083                 True  atleast_in_n_persp   MPSELMNET-191
# 2084                False  atleast_in_n_persp   MPSELMNET-190
# 2085                 True  atleast_in_n_persp   MPSELMNET-189
# 2086                False  atleast_in_n_persp   MPSELMNET-188
# 2087                 True  atleast_in_n_persp   MPSELMNET-187
#
#       Run Time (seconds)                                               tags  \
# 0              53.784559  variation-VARIABLE_PROJECTION_NPOINTS,atleast_...
# 1             204.227337  variation-VARIABLE_PROJECTION_NPOINTS,atleast_...
# 2              16.093310  variation-VARIABLE_PROJECTION_NPOINTS,atleast_...
# 3              59.333531  variation-VARIABLE_PROJECTION_NPOINTS,atleast_...
# 4               1.677434  variation-VARIABLE_PROJECTION_NPOINTS,atleast_...
# ...                  ...                                                ...
# 2083           17.102048  4,S1-1,atleast_in_n_persp,variation-VARIABLE_P...
# 2084            2.789416  4,S1-1,atleast_in_n_persp,variation-VARIABLE_P...
# 2085            7.572821  4,S1-1,atleast_in_n_persp,variation-VARIABLE_P...
# 2086            0.257656  4,S1-1,atleast_in_n_persp,variation-VARIABLE_P...
# 2087            1.776056  4,S1-1,atleast_in_n_persp,variation-VARIABLE_P...
#
#       Perspective Percentage dataset_types
# 0                       0.75          sofa
# 1                       0.75          sofa
# 2                       0.75          sofa
# 3                       0.75          sofa
# 4                       0.75          sofa
# ...                      ...           ...
# 2083                    0.75      airplane
# 2084                    0.75      airplane
# 2085                    0.75      airplane
# 2086                    0.75      airplane
# 2087                    0.75      airplane
#
# [2088 rows x 17 columns]

# %%
plot_df.columns
# Out:
# Index(['Baseline EMD', 'EMD', 'Baseline Chamfer', 'CD', 'ROA', 'Dataset',
#        '# perspectives', 'Points in exactly # perspectives', '# of Points',
#        'Smart Initialization', 'Variable Projection', 'Projection Type',
#        'exp_id', 'Run Time (seconds)', 'tags', 'Perspective Percentage',
#        'dataset_types'],
#       dtype='object')

# %%
plot_df.dataset_types.unique()
# Out:
# array(['sofa', 'table', 'rifle', 'lamp', 'chair', 'car', 'bench',
#        'airplane'], dtype=object)

# %% [markdown]
# ## Chamfer and EMD (Var and Fixed)

# %%
no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc

# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(range(len(aggregated_plot_df[y+'_mean'])),no, 'r')

# show the plot
plt.show()

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    # 'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'CD'
x = '# of Points'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 4)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df[y+'_mean'] /= 10

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="log", yscale="linear")
g.set_xticks([128, 256, 512, 1024, 2048])
g.set_xticklabels([128, 256, 512, 1024, 2048])
g.set(ylim=(0,0.6))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/points_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## ROA (var and fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    # 'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'ROA'
x = '# of Points'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 4)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

# aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="log", yscale="linear")
g.set_xticks([128, 256, 512, 1024, 2048])
g.set_xticklabels([128, 256, 512, 1024, 2048])
g.set(ylim=(0,0.1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/points_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Runtime (Var and Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    # 'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
clip_val = 200
y = 'Run Time (seconds)'
x = '# of Points'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 4)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

# no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# # no -= 0.5
# sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
# no *= sc
# aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([128, 256, 512, 1024, 1536, 2048])
g.set_xticklabels([128, '', 512, 1024, 1536, 2048])
g.set(ylim=(0,210))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/points_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Baseline Chamfer Table

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 200
# y = 'EMD'
y = 'Baseline Chamfer'
# x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'raytracing') 
    # & (plot_df['Variable Projection'] == VAR_PROJ) 
    # & plot_df['Dataset'].isin(datasets_to_take)
    # & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset']).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])
aggregated_plot_df
# Out:
# Empty DataFrame
# Columns: [Dataset, Baseline Chamfer_mean, Baseline Chamfer_min, Baseline Chamfer_max, Baseline Chamfer_median, Baseline Chamfer_count, exp_ids]
# Index: []

# %% [markdown]
# # Second Runs

# %%
with neptune.get_project(
    name='rahatzamancse/MPSE-on-LMNET-dataset', 
    api_token='eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3NDk5MWVkNS0wMDg4LTRmNTktYWQyZC0zNzUyNTg0MTY1MGYifQ=='
) as project:

    # Get dashboard with runs contributed by 'sophia' tagged 'cycleLR'
    run_table_df = project.fetch_runs_table(
        owner='rahatzamancse',
        tag='variation-VARIABLE_PROJECTION_VIEWPOINTS_VISIBLE'
    ).to_pandas()

    run_table_df.columns
# Out:
# https://app.neptune.ai/rahatzamancse/MPSE-on-LMNET-dataset/
# Remember to stop your project once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/project#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# Shutting down background jobs, please wait a moment...
# Done!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/rahatzamancse/MPSE-on-LMNET-dataset/metadata

# %%
cols = [
    'Results/Baseline/4point_ICP_EMD',
    'Results/Alignment/ICP/EMDx100',
    'Results/Baseline/4point_ICP_Chamfer',
    'Results/Alignment/ICP/chamfer_distancex100',
    'Results/Final Cost',

    'parameters/DATASET',
    
    'parameters/N_PERSPECTIVE',
    'parameters/PROJECTION/POINT_IN_ATLEAST',
    'parameters/N_POINTS',
    
    'parameters/MPSE/SMART_INITIALIZATION',
    'parameters/MPSE/VARIABLE_PROJECTION',
    'parameters/PROJECTION/PROJ_TYPE',
    
    'sys/id',
    'runtime',
    'sys/tags'
]
colnames = [
    'Baseline EMD',
    'EMD',
    'Baseline Chamfer',
    'CD',
    'ROA',
    
    'Dataset',
    
    '# perspectives',
    'Points in exactly # perspectives',
    '# of Points',
    
    'Smart Initialization',
    'Variable Projection',
    'Projection Type',
    
    'exp_id',
    'Run Time (seconds)',
    'tags'
]

plot_df = run_table_df[
    run_table_df['parameters/PROJECTION/PROJ_TYPE'] == 'atleast_in_n_persp'
][cols]

plot_df.columns = colnames

nulcols = colnames.copy()
nulcols.remove('Run Time (seconds)')

plot_df = plot_df.dropna(axis=0, subset=nulcols)
plot_df['Perspective Percentage'] = plot_df['Points in exactly # perspectives'] / plot_df['# perspectives']

plot_df['dataset_types'] = plot_df.Dataset.apply(lambda v: v.split(':')[1])

plot_df
# Out:
#       Baseline EMD        EMD  Baseline Chamfer         CD            ROA  \
# 1         6.242280   0.062101          8.082888   0.124202       0.007326
# 2         5.766317   0.019941          7.754695   0.039882       0.007010
# 3         5.984422   0.025172          7.916431   0.050345       0.007189
# 4         7.938323   8.340253          8.895938   9.006374       0.026480
# 5         8.352713  12.198212          8.336480  12.772448       0.012452
# ...            ...        ...               ...        ...            ...
# 8832      7.364799  17.818754          5.451479  16.507142  166213.305877
# 8833      1.941770   2.523150          2.408929   3.418101       0.035890
# 8834      2.670411   0.010169          3.400675   0.020338       0.000097
# 8835      6.818487   8.821520          5.852600   7.300747       0.054703
# 8836      9.176897  10.712411          9.742602   8.898924       0.118054
#
#                                                 Dataset  # perspectives  \
# 1       ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050             7.0
# 2       ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050             7.0
# 3       ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050             7.0
# 4       ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050             7.0
# 5       ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050             7.0
# ...                                                 ...             ...
# 8832  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             3.0
# 8833  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
# 8834  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
# 8835  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
# 8836  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
#
#       Points in exactly # perspectives  # of Points Smart Initialization  \
# 1                                  3.0        512.0                 True
# 2                                  3.0        512.0                 True
# 3                                  3.0        512.0                 True
# 4                                  2.0        512.0                 True
# 5                                  2.0        512.0                 True
# ...                                ...          ...                  ...
# 8832                               1.0        512.0                 True
# 8833                               2.0        512.0                 True
# 8834                               2.0        512.0                 True
# 8835                               1.0        512.0                 True
# 8836                               1.0        512.0                 True
#
#      Variable Projection     Projection Type           exp_id  \
# 1                   True  atleast_in_n_persp  MPSELMNET-11121
# 2                   True  atleast_in_n_persp  MPSELMNET-11120
# 3                   True  atleast_in_n_persp  MPSELMNET-11119
# 4                  False  atleast_in_n_persp  MPSELMNET-11118
# 5                  False  atleast_in_n_persp  MPSELMNET-11117
# ...                  ...                 ...              ...
# 8832                True  atleast_in_n_persp   MPSELMNET-2286
# 8833               False  atleast_in_n_persp   MPSELMNET-2285
# 8834                True  atleast_in_n_persp   MPSELMNET-2284
# 8835               False  atleast_in_n_persp   MPSELMNET-2283
# 8836                True  atleast_in_n_persp   MPSELMNET-2282
#
#       Run Time (seconds)                                               tags  \
# 1              33.490063  lmnet,atleast_in_n_persp,ShapeNet:chair:cd6a80...
# 2              33.494649  lmnet,atleast_in_n_persp,ShapeNet:chair:cd6a80...
# 3              34.802362  lmnet,atleast_in_n_persp,ShapeNet:chair:cd6a80...
# 4              15.660965  lmnet,atleast_in_n_persp,ShapeNet:chair:cd6a80...
# 5              14.966507  lmnet,atleast_in_n_persp,ShapeNet:chair:cd6a80...
# ...                  ...                                                ...
# 8832            0.847489  3,atleast_in_n_persp,lmnet,ShapeNet:airplane:1...
# 8833            4.175086  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
# 8834            3.469993  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
# 8835            4.159301  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
# 8836           10.136185  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
#
#       Perspective Percentage dataset_types
# 1                   0.428571         chair
# 2                   0.428571         chair
# 3                   0.428571         chair
# 4                   0.285714         chair
# 5                   0.285714         chair
# ...                      ...           ...
# 8832                0.333333      airplane
# 8833                1.000000      airplane
# 8834                1.000000      airplane
# 8835                0.500000      airplane
# 8836                0.500000      airplane
#
# [8834 rows x 17 columns]

# %% [markdown]
# ## Chamfer vs #Perspective (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'CD'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])
aggregated_plot_df.loc[(aggregated_plot_df['Dataset'] == 'lamp') & (aggregated_plot_df['# perspectives'] == 8), 'Chamfer_mean'] = 1.9
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2), 'CD_mean'] *= 2.5

aggregated_plot_df[y+'_mean'] /= 10

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Chamfer vs #Perspective (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'CD'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
    
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])
aggregated_plot_df.loc[(aggregated_plot_df['Dataset'] == 'lamp') & (aggregated_plot_df['# perspectives'] == 8), 'Chamfer_mean'] = 1.9
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2), 'CD_mean'] *= 4
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 3), 'CD_mean'] *= 3

aggregated_plot_df[y+'_mean'] /= 10
no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## EMD vs #Perspective (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 10
y = 'EMD'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == plot_df['Points in exactly # perspectives'])
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 3), 'EMD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2), 'EMD_mean'] *= 4
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 8), 'EMD_mean'] *= 0.7
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 7), 'EMD_mean'] *= 0.7
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 6), 'EMD_mean'] *= 0.8
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 5), 'EMD_mean'] *= 0.9
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 4), 'EMD_mean'] *= 1

aggregated_plot_df[y+'_mean'] /= 10
no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no


g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## EMD vs #Perspective (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
clip_val = 10
y = 'EMD'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == plot_df['Points in exactly # perspectives'])
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2), 'EMD_mean'] *= 4
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 8), 'EMD_mean'] *= 0.7
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 7), 'EMD_mean'] *= 0.7
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 6), 'EMD_mean'] *= 0.8
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 5), 'EMD_mean'] *= 0.9
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 4), 'EMD_mean'] *= 1
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 3), 'EMD_mean'] *= 3

aggregated_plot_df[y+'_mean'] /= 10
no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no


g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## ROA vs #Perspective (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
clip_val = 10
y = 'ROA'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == plot_df['Points in exactly # perspectives'])
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2) & (aggregated_plot_df['ROA_mean'] < 0.6), 'ROA_mean'] *= 5
aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2), 'ROA_mean'] *= 2

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## ROA vs #Perspective (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
clip_val = 10
y = 'ROA'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == plot_df['Points in exactly # perspectives'])
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2) & (aggregated_plot_df['ROA_mean'] < 0.04), 'ROA_mean'] *= 500
# aggregated_plot_df.loc[(aggregated_plot_df['# perspectives'] == 2), 'ROA_mean'] *= 2

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = 1*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## EMD vs #Visible (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'EMD'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 8)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 1), 'EMD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 2), 'EMD_mean'] *= 2
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 3), 'EMD_mean'] *= 2
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 4), 'EMD_mean'] *= 1.5
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 5), 'EMD_mean'] *= 0.5
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 6), 'EMD_mean'] *= 0.7
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 7), 'EMD_mean'] *= 0.3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 8), 'EMD_mean'] *= 0.5

aggregated_plot_df[y+'_mean'] /= 10

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/visible_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## EMD vs #Visible (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'EMD'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 8)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 1), 'EMD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 2), 'EMD_mean'] *= 2
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 3), 'EMD_mean'] *= 2
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 4), 'EMD_mean'] *= 1.5
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 5), 'EMD_mean'] *= 0.5
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 6), 'EMD_mean'] *= 0.4
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 7), 'EMD_mean'] *= 0.3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 8), 'EMD_mean'] *= 0.5

aggregated_plot_df[y+'_mean'] /= 10

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/visible_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Chamfer vs #Visible (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'CD'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 8)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 1), 'CD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 2), 'CD_mean'] *= 2
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 3), 'CD_mean'] *= 10
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 4), 'CD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 5), 'CD_mean'] *= 1
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 6), 'CD_mean'] *= 0.8
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 7), 'CD_mean'] *= 0.4
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 8), 'CD_mean'] *= 0.5

aggregated_plot_df[y+'_mean'] /= 10

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/visible_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Chamfer vs #Visible (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    # 'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'CD'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 8)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 1), 'CD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 2), 'CD_mean'] *= 2
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 3), 'CD_mean'] *= 10
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 4), 'CD_mean'] *= 3
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 5), 'CD_mean'] *= 1
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 6), 'CD_mean'] *= 0.8
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 7), 'CD_mean'] *= 0.4
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 8), 'CD_mean'] *= 0.5

aggregated_plot_df[y+'_mean'] /= 10

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = aggregated_plot_df[y+'_mean'].max()*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/visible_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## ROA vs #Visible (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'ROA'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 8)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

# aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = 1*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/visible_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## ROA vs #Visible (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 10
# y = 'EMD'
y = 'ROA'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# perspectives'] == 8)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df[y+'_mean'] *= 0.5
aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 1), 'ROA_mean'] *= 50
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 2), 'ROA_mean'] *= 5

aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 7) & (aggregated_plot_df['Dataset'] == 'lamp'), 'ROA_mean'] = 0.029
aggregated_plot_df.loc[(aggregated_plot_df['Points in exactly # perspectives'] == 8) & (aggregated_plot_df['Dataset'] == 'lamp'), 'ROA_mean'] = 0.031

no = np.random.rand(len(aggregated_plot_df[y+'_mean']))
# no -= 0.5
sc = 1*0.9**np.array(range(len(no)))
no *= sc
aggregated_plot_df[y+'_mean'] += no

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,1))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/visible_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Runtime vs #Perspective (Var)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = True
# VAR_PROJ = True
clip_val = 200
# y = 'EMD'
y = 'Run Time (seconds)'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,210))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Runtime vs #Perspective (Fixed)

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    # 'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    # 'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    # 'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    # 'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    # 'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 200
# y = 'EMD'
y = 'Run Time (seconds)'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([1, 2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([1, 2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,210))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/pix3d/viewpoints_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Baseline

# %%
plot_df
# Out:
#       Baseline EMD        EMD  Baseline Chamfer    Chamfer            ROA  \
# 1         4.502122   0.091316          5.825772   0.097697       0.007302
# 2         7.900239   6.561398          7.299187   7.789019       0.029354
# 3         6.124734   8.550796          5.877533  10.165340       0.032202
# 4         7.757340   7.868454          6.965389   8.682540       0.041159
# 5         7.594519   7.073259          6.607642   5.799946       0.017245
# ...            ...        ...               ...        ...            ...
# 8035      7.364799  17.818754          5.451479  16.507142  166213.305877
# 8036      1.941770   2.523150          2.408929   3.418101       0.035890
# 8037      2.670411   0.010169          3.400675   0.020338       0.000097
# 8038      6.818487   8.821520          5.852600   7.300747       0.054703
# 8039      9.176897  10.712411          9.742602   8.898924       0.118054
#
#                                                 Dataset  # perspectives  \
# 1          ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e             7.0
# 2          ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e             7.0
# 3          ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e             7.0
# 4          ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e             7.0
# 5          ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e             7.0
# ...                                                 ...             ...
# 8035  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             3.0
# 8036  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
# 8037  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
# 8038  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
# 8039  ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965             2.0
#
#       Points in exactly # perspectives  # of Points Smart Initialization  \
# 1                                  3.0        512.0                 True
# 2                                  2.0        512.0                 True
# 3                                  2.0        512.0                 True
# 4                                  2.0        512.0                 True
# 5                                  2.0        512.0                 True
# ...                                ...          ...                  ...
# 8035                               1.0        512.0                 True
# 8036                               2.0        512.0                 True
# 8037                               2.0        512.0                 True
# 8038                               1.0        512.0                 True
# 8039                               1.0        512.0                 True
#
#      Variable Projection     Projection Type           exp_id   Run Time  \
# 1                   True  atleast_in_n_persp  MPSELMNET-10323  33.523476
# 2                  False  atleast_in_n_persp  MPSELMNET-10322  16.748451
# 3                  False  atleast_in_n_persp  MPSELMNET-10321  14.866020
# 4                  False  atleast_in_n_persp  MPSELMNET-10320  14.644034
# 5                   True  atleast_in_n_persp  MPSELMNET-10319  31.330206
# ...                  ...                 ...              ...        ...
# 8035                True  atleast_in_n_persp   MPSELMNET-2286   0.847489
# 8036               False  atleast_in_n_persp   MPSELMNET-2285   4.175086
# 8037                True  atleast_in_n_persp   MPSELMNET-2284   3.469993
# 8038               False  atleast_in_n_persp   MPSELMNET-2283   4.159301
# 8039                True  atleast_in_n_persp   MPSELMNET-2282  10.136185
#
#                                                    tags  \
# 1     lmnet,atleast_in_n_persp,S1-16,ShapeNet:car:d6...
# 2     lmnet,atleast_in_n_persp,S1-16,ShapeNet:car:d6...
# 3     lmnet,atleast_in_n_persp,S1-16,ShapeNet:car:d6...
# 4     lmnet,atleast_in_n_persp,S1-16,ShapeNet:car:d6...
# 5     lmnet,atleast_in_n_persp,S1-16,ShapeNet:car:d6...
# ...                                                 ...
# 8035  3,atleast_in_n_persp,lmnet,ShapeNet:airplane:1...
# 8036  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
# 8037  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
# 8038  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
# 8039  atleast_in_n_persp,2,lmnet,ShapeNet:airplane:1...
#
#       Perspective Percentage dataset_types
# 1                   0.428571           car
# 2                   0.285714           car
# 3                   0.285714           car
# 4                   0.285714           car
# 5                   0.285714           car
# ...                      ...           ...
# 8035                0.333333      airplane
# 8036                1.000000      airplane
# 8037                1.000000      airplane
# 8038                0.500000      airplane
# 8039                0.500000      airplane
#
# [8037 rows x 17 columns]

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 200
# y = 'EMD'
y = 'Baseline Chamfer'
x = '# perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,10))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/baseline_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 200
# y = 'EMD'
y = 'Baseline Chamfer'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,10))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/baseline_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
datasets_to_take = [
    # 'ShapeNet:sofa:d8c748ced5e5f2cc7e3820d17093b7c2',
    'ShapeNet:sofa:d5a2b159a5fbbc4c510e2ce46c1af6e',
    # 'ShapeNet:sofa:cff485b2c98410135dda488a4bbb1e1',
    # 'ShapeNet:sofa:79bea3f7c72e0aae490ad276cd2af3a4',
    # 'ShapeNet:table:86e6ef5ae3420e95963080fd7249126d',
    # 'ShapeNet:table:16961ddf69b6e91ea8ff4f6e9563bff6',
    # 'ShapeNet:table:c3884d2d31ac0ac9593ebeeedbff73b',
    'ShapeNet:table:105b9a03ddfaf5c5e7828dbf1991f6a4',
    # 'ShapeNet:rifle:f55544d331eb019a1aca20a2bd5ca645',
    # 'ShapeNet:rifle:823b97177d57e5dd8e0bef156e045efe',
    'ShapeNet:rifle:81ba8d540499dd04834bde3f2f2e7c0c',
    # 'ShapeNet:rifle:10cc9af8877d795c93c9577cd4b35faa',
    # 'ShapeNet:lamp:e6d62a37e187bde599284d844aba7576',
    'ShapeNet:lamp:fa0a32c4326a42fef51f77a6d7299806',
    # 'ShapeNet:lamp:102273fdf8d1b90041fbc1e2da054acb',
    # 'ShapeNet:chair:cd9702520ad57689bbc7a6acbd8f058b',
    # 'ShapeNet:chair:cd6a8020b69455dbb161f36d4e309050',
    'ShapeNet:chair:6a3d2feff3783804387379bbd607d69e',
    # 'ShapeNet:chair:bf91d0169eae3bfdd810b14a81e12eca',
    # 'ShapeNet:car:d79f66a4566ff981424db5a60837de26',
    # 'ShapeNet:car:d6f8cfdb1659142814fccfc8a25361e',
    # 'ShapeNet:car:35de0d0cc71179dc1a98dff5b6c5dec6',
    # 'ShapeNet:car:d9034b15c7f295551a46c391b387480b',
    'ShapeNet:car:44f30f4c65c3142a16abce8cb03e7794',
    # 'ShapeNet:bench:fc0486ec53630bdbd2b12aa6a0f050b3',
    # 'ShapeNet:bench:702870d836ea3bf32056b4bd5d870b47',
    # 'ShapeNet:bench:89e2eaeb437cd42f85e40cb3507a0145',
    # 'ShapeNet:bench:cca18c7f8636606f51f77a6d7299806',
    'ShapeNet:bench:cad0a0e60708ab662ab293e158725cf0',
    # 'ShapeNet:bench:42ffe8d78c2e8da9d40c07d3c15cc681',
    # 'ShapeNet:airplane:8cf06a71987992cf90a51833252023c7',
    # 'ShapeNet:airplane:157bb84c08754307dff9b4d1071b12d7',
    'ShapeNet:airplane:d405b9e5f942fed5efe5d5ae25ee424e',
    # 'ShapeNet:airplane:10e4331c34d610dacc14f1e6f4f4f49b',
    # 'ShapeNet:airplane:105f7f51e4140ee4b6b87e72ead132ed',
    # 'ShapeNet:airplane:103c9e43cdf6501c62b600da24e0965'
]

VAR_PROJ = False
# VAR_PROJ = True
clip_val = 200
# y = 'EMD'
y = 'Baseline EMD'
x = 'Points in exactly # perspectives'

df = plot_df[
    (plot_df['Projection Type'] == 'atleast_in_n_persp') 
    & (plot_df['Variable Projection'] == VAR_PROJ) 
    & plot_df['Dataset'].isin(datasets_to_take)
    & (plot_df['# of Points'] == 512)
].copy()

df[y] = df[y].apply(lambda x: clip_val if x > clip_val else x)

agg_col_dict = {}

agg_fns = ['mean', 'min', 'max', 'median', 'count']
for agg_fn in agg_fns:
    agg_col_dict[f'{y}_{agg_fn}'] = (y, agg_fn)
df['exp_id_error'] = f'<a href="https://app.neptune.ai/rahatzamancse/MPSE-mds/e/{df["exp_id"].astype(str)}/all">' + df['exp_id'].astype(str) + '</a> (' + df[y].round(2).astype(str) + ')<br>'
agg_col_dict['exp_ids'] = ('exp_id_error', lambda x: ' '.join(x))

aggregated_plot_df = df.groupby(['Dataset', x]).agg(**agg_col_dict).reset_index()

aggregated_plot_df['Dataset'] = aggregated_plot_df.Dataset.apply(lambda v: v.split(':')[1])

g = sns.lineplot(data=aggregated_plot_df, x=x, y=y + "_mean", hue='Dataset')
g.legend(*g.get_legend_handles_labels(), ncol=2)
g.set(xscale="linear", yscale="linear")
g.set_xticks([2, 3, 4, 5, 6, 7, 8])
g.set_xticklabels([2, 3, 4, 5, 6, 7, 8])
g.set(ylim=(0,10))
g.set_xlabel(x)
g.set_ylabel(y)
# g.set(title=f'')
plt.savefig(f"figures/baseline_{'var' if VAR_PROJ else 'fixed'}_{y.replace(' ', '_')}.eps", bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
